# %% [markdown]
# ## Problem 1: Check sign
#
# **Question:** Write a program that checks if a number is positive, negative, or zero.
#
# **Approach:** Think about comparing the number with 0 using if, elif, and else.

# %%
# Enter your answer here
num=float(input("enter a number here"))

if num>=0:
    print("zero")
elif num<0:
    print("negative")
else:
    print("positive")
# Out:
# negative

# %% [markdown]
# ## Problem 2: Leap Year
#
# **Question:** Check if a given year is a leap year.
#
# **Approach:** Apply the rules: divisible by 4, but centuries must be divisible by 400.
#
# Rules: Year divisible by 4 is leap, but if divisible by 100 it must also be divisible by 400.

# %%
# Enter your answer here
year=int(input("enter a number here "))

if (year % 4==0 and year% 100 != 0) or (year%400==0) :
    print("leap year")
else:
    print("not a leap year")
# Out:
# leap year

# %% [markdown]
# ## Problem 3: Grade Bands
#
# **Question:** Print grade category based on marks: Excellent, Good, Average, Fail.
#
# **Approach:** Build multiple conditions using elif to check ranges.
#
# Take marks (0-100) and print:
# - 90–100 → Excellent
# - 75–89 → Good
# - 50–74 → Average
# - else → Fail

# %%
# Enter your answer here
number=int(input("enter your marks here "))
if number>90 and number<100:
    print("excellent")
elif number>75 and number<89:
    print("good")
elif number>50 and number<74:
    print("average")
else:
    print("fail")
# Out:
# average

# %% [markdown]
# ## Problem 4: Validate Login
#
# **Question:** Check username=='admin' and password=='1234'.
#
# **Approach:** Use logical AND to validate both conditions.
#
#
# Input: username & password.
#
# If username == 'admin' and password == '1234'
# print 'Login successful',
# else 'Invalid credentials'.

# %%
# Enter your answer here
username= input("enter the usename here:")
password=int(input("enter the number here"))

if username=="admin" and password==1234:
    print("Login successfull")
else:
    print("invalid user")
# Out:
# Login successfull

# %% [markdown]
# ## Problem 5: Movie Ticket Discount
#
# **Question:** Apply discount based on age.
#
# **Approach:** Use ordered elif statements from smallest to largest age group.
#
# Apply discounts based on age:
# - Age < 12 → 50% discount
# - Age between 12 and 18 → 30% discount
# - Age between 18 and 60 → no discount
# - Age > 60 → 40% discount

# %%
# Enter your answer here
age = int(input("Enter the age here: "))

if age < 12:
    print("Discount 50%")
elif age < 18:
    print("Discount 30%")
elif age < 60:
    print("No discount")
else:
    print("Discount 40%")
# Out:
# Discount 50%

# %% [markdown]
# ## Problem 6: Placement Eligibility
#
# **Question:** Check CGPA, backlog status, and project count.
#
# **Approach:** All conditions must be true → use AND operator.
#
#
# Conditions:
# - CGPA ≥ 7
# - No backlog (enter 'yes' or 'no')
# - Completed >= 2 major projects
# Print whether the student is eligible.

# %%
# Enter your answer here
cgpa=int(input("enter the cgpa here"))
backlogs=input("yes or no here ")
major_project=int(input("quantity of major oroject done"))

if cgpa>=7 and backlogs=="no" and major_project>=2:
    print("you atre eligible for placement")
else:
    print("try again")
# Out:
# try again

# %% [markdown]
# ## Problem 7: Delivery Charge System
#
# **Question:** Calculate final delivery charge based on prime membership, amount, and distance.
#
# **Approach:** Start with prime-check, then inside it apply nested if blocks.
#
# Inputs:
# - order_amount (int)
# - is_prime_member (yes/no)
# - distance_km (float)
#
# Rules:
# - If prime member → Free delivery
# - Else:
#   - If amount ≥ 500:
#     - If distance ≤ 5 km → Free
#     - Else → ₹20 extra
#   - Else:
#     - If distance ≤ 5 km → ₹30
#     - Else → ₹50

# %%
# Enter your answer 
order_amount=int(input("enter the amount here"))
prime_membership=input("yes or no")
distance_kilometer=float(input("enter the kilometer here"))

if prime_membership=="yes":
    print("free delivery")
else:
    if order_amount>=500:
        if distance_kilometer<=5:
            print("free delivery")
        else:
            print("20 rupees extra")
    else:
        if distance_kilometer<=5:
            print("charges rupees 30")
        else:
            print("charges rupees 50")
# Out:
# 20 rupees extra

# %% [markdown]
# ## Problem 8: ATM Withdrawal Simulation
#
# **Question:** Simulate ATM rules: multiples of 100, sufficient balance, manager approval.
#
# **Approach:** Check errors first, then nested conditions for amount > 10000.
#
# Inputs:
# - balance
# - amount
#
# Logic:
# - If amount % 100 != 0 → reject (ATM works with ₹100 multiples)
# - If amount > balance → reject
# - Else:
#   - if amount > 10000 → ask for manager approval
#   - else → withdraw success

# %%
# Enter your answer here
balance=int(input("enter the balance here"))
amount=int(input("enter the amount here"))

if amount%100 !=0:
    print("reject atm work with 100 multiples ")
    if amount>balance:
        print("rejects")
    else:
        if amount>10000:
            print("ask for mnger approval")
        else:
            print("withdrawl successful")
else:
    print("withdraw successful")
# Out:
# withdraw successful

# %% [markdown]
# ## Problem 9: Employee Performance Rating
#
# **Question:** Assign performance rating based on sales, feedback, attendance.
#
# **Approach:** Prioritize attendance rule, then apply nested conditions.
#
# Inputs:
# - sales (₹)
# - feedback (0-5 scale)
# - attendance (%)
#
# Logic:
# - If attendance < 70 → 'Poor'
# - Else:
#   - If sales > 100000 AND feedback > 4.5 → 'Excellent'
#   - If sales > 70000 OR feedback > 4 → 'Good'
#   - Else → 'Average'

# %%
# Enter your answer here
sales=int(input("enter sales here"))
feedback=int(input("select feedback between 0 t0 5"))
attanance_percentage=int(input("attandace between 0 to 100 %"))

if attanance_percentage<70:
    print("poor")
else:
    if sales>100000 and feedback>4.5:
        print("excellent")
    elif sales>70000 or feedback>4:
        print("good")
    else:
        print("average")
# Out:
# excellent

# %% [markdown]
# ## Problem 10: Credit Card Eligibility
#
# **Question:** Determine card eligibility based on age, salary, credit score.
#
# **Approach:** First filter by age, then use nested if blocks for salary and credit score.
#
# Inputs:
# - salary
# - credit_score
# - age
#
# Logic:
# - If age < 21 → Not eligible
# - Else:
#   - If salary ≥ 40,000:
#     - If credit_score ≥ 750 → Gold Card
#     - Else → Silver Card
#   - Else:
#     - If credit_score ≥ 800 → Silver Card
#     - Else → Not eligible

# %%
# Enter your answer here
salary=int(input("enter salary here"))
credit_score=int(input("enter credit score here"))
age=int(input("enter age here"))

if age<21:
    print("not eligible")
else:
    if salary>=40000:
        if credit_score>=750:
            print("gold card")
        else:
            print("silver card")
    else:
        if credit_score>=800:
            print("silver card")
        else:
            print("not eligible")
# Out:
# gold card
